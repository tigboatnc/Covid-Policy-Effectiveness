# %% [markdown]
# # Data Scraping
#
# 1. Better data at one place
#
# 1. I found this resource https://data.census.gov/cedsci/map?vintage=2020
# 2. I found that urls are similar and have a pattern
# 3. I made a scraper

# %%
# Setting Up Imports 

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager



import copy

from urllib.parse import urlparse
import numpy as np
import pandas as pd
import re 
from pathlib import Path
import os
import time
from datetime import date
from datetime import timedelta
from datetime import datetime
import dateutil.parser as parser

today = date.today()
cwd = os.getcwd()


# Setting up browser environment

userprofile = 'teamcovid'
options = webdriver.ChromeOptions()
options.add_argument(f"user-data-dir={cwd}/."+userprofile+"UserProfile")
driver = webdriver.Chrome(ChromeDriverManager().install() , options=options)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/96.0.4664.45/chromedriver_mac64.zip
# Driver has been saved in cache [/Users/flipflops/.wdm/drivers/chromedriver/mac64/96.0.4664.45]
# /var/folders/66/w1588p9n1654b1yky4q5nz580000gn/T/ipykernel_13537/1432248455.py:37: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install() , options=options)

# %%
src = 'https://data.census.gov/cedsci/profile?g=0400000US'

# %%
for i in range (10,80):
    
    
    MEDIANAGE = -1
    POVERTY = -1 
    MEDIAN_INCOME = -1 
    VETERANS = -1 
    
    
    
    if len(str(i))==1:
        index_url = '0' + str(i)
    else:
        index_url = str(i)
            
    driver.get(src+index_url)
    
    time.sleep(2)
    noResList = driver.find_elements(By.XPATH,f"//h1[@class='{'message'}']")
    results = []
    for hits in noResList:
        results.append(hits.text)
    
    if ('No Results Found' in results):
        print('Not a valid url')
        print('---------\n\n')
        continue

    print('valid url')
#         //SCRAPE HERE 

    time.sleep(10)
    
    StateName = driver.find_element(By.XPATH,f"//h1[@class='{'profile-title'}']").text
    print(f'Found State, {StateName}')
    
    headerClass = 'aqua-layout highlight vertical align-center justify-center'
    headerList = driver.find_elements(By.XPATH,f"//div[@class='{headerClass}']")
    
    context = []
    value = [] 
    for header in headerList:

        all_children_by_xpath = header.find_elements(By.XPATH,".//*")
        for indice,headerInside in enumerate(all_children_by_xpath):
            textdata = headerInside.text
            if indice==2:
                context.append(textdata)
            if indice ==3:
                value.append(textdata)
            
            
    print(context)
    print(value)
    
    FINAL = {}
    if len(context) == len(value):
        for indexing in range(len(context)):
            FINAL[context[indexing]] =  value[indexing]

            
    df_FINAL = pd.DataFrame(FINAL, index=[0])
    
    df_FINAL.to_csv(f'{StateName}.csv')
    
    SHIT_METHOD_LIST = driver.find_elements(By.XPATH,f"//span[@class='{'measure-estimate-value'}']")
    for indice,dataElement in enumerate(SHIT_METHOD_LIST):
        if indice ==0:
            MEDIAN_AGE = dataElement.text
        if indice ==14:
            VETERANS = dataElement.text
        if indice ==16:
            MEDIAN_INCOME = dataElement.text
        if indice ==18:
            POVERTY = dataElement.text

            
            
        
    
    
    print('---------\n\n')
# Out:
# valid url
# Found State, Delaware
# ['Total Population', 'Median Household Income', "Bachelor's Degree or Higher", 'Employment Rate', 'Total Housing Units', 'Without Health Care Coverage', 'Total Employer Establishments', 'Total Households', 'Hispanic or Latino (of any race)']
# ['989,948', '$70,176', '33.2%', '58.8%', '448,735', '6.6%', '26,142', '376,239', '104,290']
# ---------
#
#
# valid url
# Found State, District of Columbia
# ['Total Population', 'Median Household Income', "Bachelor's Degree or Higher", 'Employment Rate', 'Total Housing Units', 'Without Health Care Coverage', 'Total Employer Establishments', 'Total Households', 'Hispanic or Latino (of any race)']
# ['689,545', '$92,266', '59.7%', '66.0%', '350,364', '3.5%', '23,993', '291,570', '77,652']
# ---------
#
#
# valid url
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# /var/folders/66/w1588p9n1654b1yky4q5nz580000gn/T/ipykernel_13537/3126971130.py in <module>
#      32     time.sleep(10)
#      33
# ---> 34     StateName = driver.find_element(By.XPATH,f"//h1[@class='{'profile-title'}']").text
#      35     print(f'Found State, {StateName}')
#      36
#
# /usr/local/Caskroom/miniconda/base/envs/602/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#    1236             value = '[name="%s"]' % value
#    1237
# -> 1238         return self.execute(Command.FIND_ELEMENT, {
#    1239             'using': by,
#    1240             'value': value})['value']
#
# /usr/local/Caskroom/miniconda/base/envs/602/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     416         response = self.command_executor.execute(driver_command, params)
#     417         if response:
# --> 418             self.error_handler.check_response(response)
#     419             response['value'] = self._unwrap_value(
#     420                 response.get('value', None))
#
# /usr/local/Caskroom/miniconda/base/envs/602/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     241                 alert_text = value['alert'].get('text')
#     242             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243         raise exception_class(message, screen, stacktrace)
#     244
#     245     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=96.0.4664.93)
# Stacktrace:
# 0   chromedriver                        0x0000000105eb8269 __gxx_personality_v0 + 582729
# 1   chromedriver                        0x0000000105e43c33 __gxx_personality_v0 + 106003
# 2   chromedriver                        0x0000000105a00cdf chromedriver + 171231
# 3   chromedriver                        0x00000001059ef7c2 chromedriver + 100290
# 4   chromedriver                        0x00000001059f0155 chromedriver + 102741
# 5   chromedriver                        0x00000001059f1f42 chromedriver + 110402
# 6   chromedriver                        0x00000001059eac22 chromedriver + 80930
# 7   chromedriver                        0x0000000105a022b3 chromedriver + 176819
# 8   chromedriver                        0x0000000105a65b0c chromedriver + 584460
# 9   chromedriver                        0x0000000105a53c23 chromedriver + 511011
# 10  chromedriver                        0x0000000105a2975e chromedriver + 337758
# 11  chromedriver                        0x0000000105a2aa95 chromedriver + 342677
# 12  chromedriver                        0x0000000105e748ab __gxx_personality_v0 + 305803
# 13  chromedriver                        0x0000000105e8b863 __gxx_personality_v0 + 399939
# 14  chromedriver                        0x0000000105e90c7f __gxx_personality_v0 + 421471
# 15  chromedriver                        0x0000000105e8cbba __gxx_personality_v0 + 404890
# 16  chromedriver                        0x0000000105e68e51 __gxx_personality_v0 + 258097
# 17  chromedriver                        0x0000000105ea8158 __gxx_personality_v0 + 516920
# 18  chromedriver                        0x0000000105ea82e1 __gxx_personality_v0 + 517313
# 19  chromedriver                        0x0000000105ebf6f8 __gxx_personality_v0 + 612568
# 20  libsystem_pthread.dylib             0x00007fff205138fc _pthread_start + 224
# 21  libsystem_pthread.dylib             0x00007fff2050f443 thread_start + 15

# %%
df_FINAL = pd.DataFrame(FINAL, index=[0])
