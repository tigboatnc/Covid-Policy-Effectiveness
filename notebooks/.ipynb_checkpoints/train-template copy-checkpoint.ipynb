# %% [markdown]
# # A basic template to apply any models to train on the collected data

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from scipy.stats import zscore
from sklearn import preprocessing
pd.set_option('display.max_columns', None)
import graphviz
plt.rcParams['figure.figsize'] = [18, 10]

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
trainDF = pd.read_csv('../outputs/trainXY.csv',parse_dates=['date_implement'])
trainDF = trainDF.sample(frac=1)

# %%
trainDF.head()
trainDF = trainDF.dropna()

# %%
# Finalizing Indexes so we can drop state names 
trainDF = trainDF.reset_index(drop=True)

# Get a list of columns with features 
columns = trainDF.columns.to_list()

# %%
Y_columns = [x for x in columns if 'Y_' in x]

# %%
X_columns = [x for x in columns if 'Y_' not in x and 'Unnamed' not in x]

X_columns.remove('date_implement')
# X_columns.remove('policy')
X_columns.remove('state_x')
X_columns.remove('policy_type')
X_columns.remove('stateName')
X_columns.remove('CEN_stateCode')
X_columns.remove('submission_date')
X_columns.remove('state_y')

X_columns.remove('caseInterpolate_gauss3')
X_columns.remove('caseInterpolate_MA7')
X_columns.remove('caseInterpolate_savitzky31_3')
X_columns.remove('caseInterpolate_gauss8')
X_columns.remove('new_case_zscore')
X_columns.remove('new_case')

# %%
X = trainDF[X_columns]
y = trainDF[Y_columns]

# %%
y
# Out:
#       Y_TREND_caseInterpolate_MA7_14  Y_TRENDQUANT_caseInterpolate_MA7_14  \
# 0                                1.0                             0.040816
# 1                               -1.0                           -60.448980
# 2                               -1.0                           -92.316327
# 3                                1.0                            52.479592
# 4                               -1.0                            -7.969388
# ...                              ...                                  ...
# 1578                            -1.0                           -30.438776
# 1579                            -1.0                            -7.040816
# 1580                             1.0                             2.500000
# 1581                             1.0                            13.030612
# 1582                             1.0                             4.489796
#
#       Y_SLOPE_caseInterpolate_MA7_14  Y_TREND_caseInterpolate_MA7_21  \
# 0                           0.024396                             1.0
# 1                         -54.920879                            -1.0
# 2                        -107.145824                            -1.0
# 3                          44.720769                             1.0
# 4                          -7.630220                            -1.0
# ...                              ...                             ...
# 1578                      -14.497143                            -1.0
# 1579                       -7.539011                            -1.0
# 1580                        1.294615                             1.0
# 1581                       16.221538                             1.0
# 1582                        3.464725                             1.0
#
#       Y_TRENDQUANT_caseInterpolate_MA7_21  Y_SLOPE_caseInterpolate_MA7_21  \
# 0                                0.027211                        0.024396
# 1                              -51.156463                      -54.920879
# 2                              -93.843537                     -107.145824
# 3                               47.149660                       44.720769
# 4                               -6.945578                       -7.630220
# ...                                   ...                             ...
# 1578                           -11.428571                      -14.497143
# 1579                            -4.714286                       -7.539011
# 1580                             1.646259                        1.294615
# 1581                            17.210884                       16.221538
# 1582                             3.448980                        3.464725
#
#       Y_TREND_caseInterpolate_MA7_28  Y_TRENDQUANT_caseInterpolate_MA7_28  \
# 0                                1.0                             0.020408
# 1                               -1.0                           -57.709184
# 2                               -1.0                          -116.852041
# 3                                1.0                            45.163265
# 4                               -1.0                            -8.520408
# ...                              ...                                  ...
# 1578                            -1.0                           -43.306122
# 1579                            -1.0                            -4.969388
# 1580                             1.0                             1.311224
# 1581                             1.0                            16.158163
# 1582                             1.0                             2.622449
#
#       Y_SLOPE_caseInterpolate_MA7_28  Y_TREND_caseInterpolate_gauss8_14  \
# 0                           0.024396                                1.0
# 1                         -54.920879                               -1.0
# 2                        -107.145824                               -1.0
# 3                          44.720769                                1.0
# 4                          -7.630220                               -1.0
# ...                              ...                                ...
# 1578                      -14.497143                               -1.0
# 1579                       -7.539011                               -1.0
# 1580                        1.294615                                1.0
# 1581                       16.221538                                1.0
# 1582                        3.464725                                1.0
#
#       Y_TRENDQUANT_caseInterpolate_gauss8_14  \
# 0                                   0.357143
# 1                                 -43.000000
# 2                                 -64.642857
# 3                                  43.285714
# 4                                  -6.714286
# ...                                      ...
# 1578                               -7.571429
# 1579                               -1.714286
# 1580                               13.214286
# 1581                               13.571429
# 1582                                5.214286
#
#       Y_SLOPE_caseInterpolate_gauss8_14  Y_TREND_caseInterpolate_gauss8_21  \
# 0                              0.158462                                1.0
# 1                            -49.806154                               -1.0
# 2                            -84.588462                               -1.0
# 3                             43.423846                                1.0
# 4                             -7.526923                               -1.0
# ...                                 ...                                ...
# 1578                         -16.410000                               -1.0
# 1579                          -3.951538                               -1.0
# 1580                           7.043846                                1.0
# 1581                          14.922308                                1.0
# 1582                           3.990769                                1.0
#
#       Y_TRENDQUANT_caseInterpolate_gauss8_21  \
# 0                                   0.238095
# 1                                 -47.380952
# 2                                 -78.380952
# 3                                  42.952381
# 4                                  -7.285714
# ...                                      ...
# 1578                              -12.952381
# 1579                               -3.142857
# 1580                                9.380952
# 1581                               14.666667
# 1582                                4.380952
#
#       Y_SLOPE_caseInterpolate_gauss8_21  Y_TREND_caseInterpolate_gauss8_28  \
# 0                              0.158462                                1.0
# 1                            -49.806154                               -1.0
# 2                            -84.588462                               -1.0
# 3                             43.423846                                1.0
# 4                             -7.526923                               -1.0
# ...                                 ...                                ...
# 1578                         -16.410000                               -1.0
# 1579                          -3.951538                               -1.0
# 1580                           7.043846                                1.0
# 1581                          14.922308                                1.0
# 1582                           3.990769                                1.0
#
#       Y_TRENDQUANT_caseInterpolate_gauss8_28  \
# 0                                   0.178571
# 1                                 -50.678571
# 2                                 -86.321429
# 3                                  41.178571
# 4                                  -7.750000
# ...                                      ...
# 1578                              -18.857143
# 1579                               -3.642857
# 1580                                7.142857
# 1581                               14.892857
# 1582                                3.607143
#
#       Y_SLOPE_caseInterpolate_gauss8_28  Y_TREND_caseInterpolate_gauss3_14  \
# 0                              0.158462                                1.0
# 1                            -49.806154                               -1.0
# 2                            -84.588462                               -1.0
# 3                             43.423846                                1.0
# 4                             -7.526923                               -1.0
# ...                                 ...                                ...
# 1578                         -16.410000                               -1.0
# 1579                          -3.951538                               -1.0
# 1580                           7.043846                                1.0
# 1581                          14.922308                                1.0
# 1582                           3.990769                                1.0
#
#       Y_TRENDQUANT_caseInterpolate_gauss3_14  \
# 0                                   0.071429
# 1                                 -46.642857
# 2                                 -69.714286
# 3                                  49.000000
# 4                                  -6.857143
# ...                                      ...
# 1578                              -25.642857
# 1579                               -1.928571
# 1580                                5.714286
# 1581                               10.500000
# 1582                                4.928571
#
#       Y_SLOPE_caseInterpolate_gauss3_14  Y_TREND_caseInterpolate_gauss3_21  \
# 0                              0.017692                                1.0
# 1                            -53.214615                               -1.0
# 2                            -88.809231                               -1.0
# 3                             47.325385                                1.0
# 4                             -7.442308                               -1.0
# ...                                 ...                                ...
# 1578                         -17.873846                               -1.0
# 1579                          -5.983077                               -1.0
# 1580                           2.633846                                1.0
# 1581                          15.180769                                1.0
# 1582                           4.064615                                1.0
#
#       Y_TRENDQUANT_caseInterpolate_gauss3_21  \
# 0                                   0.047619
# 1                                 -49.476190
# 2                                 -72.857143
# 3                                  47.904762
# 4                                  -7.142857
# ...                                      ...
# 1578                              -14.047619
# 1579                               -4.095238
# 1580                                3.952381
# 1581                               15.809524
# 1582                                4.142857
#
#       Y_SLOPE_caseInterpolate_gauss3_21  Y_TREND_caseInterpolate_gauss3_28  \
# 0                              0.017692                                1.0
# 1                            -53.214615                               -1.0
# 2                            -88.809231                               -1.0
# 3                             47.325385                                1.0
# 4                             -7.442308                               -1.0
# ...                                 ...                                ...
# 1578                         -17.873846                               -1.0
# 1579                          -5.983077                               -1.0
# 1580                           2.633846                                1.0
# 1581                          15.180769                                1.0
# 1582                           4.064615                                1.0
#
#       Y_TRENDQUANT_caseInterpolate_gauss3_28  \
# 0                                   0.035714
# 1                                 -51.142857
# 2                                 -97.535714
# 3                                  45.178571
# 4                                  -7.607143
# ...                                      ...
# 1578                              -23.678571
# 1579                               -3.714286
# 1580                                3.000000
# 1581                               16.250000
# 1582                                3.178571
#
#       Y_SLOPE_caseInterpolate_gauss3_28
# 0                              0.017692
# 1                            -53.214615
# 2                            -88.809231
# 3                             47.325385
# 4                             -7.442308
# ...                                 ...
# 1578                         -17.873846
# 1579                          -5.983077
# 1580                           2.633846
# 1581                          15.180769
# 1582                           4.064615
#
# [1583 rows x 27 columns]

# %% [markdown]
# # Encoding Policy Names

# %%
X['policy'].unique()
# Out:
# array(['C2_Workplace closing', 'C4_Restrictions on gatherings',
#        'H6_Facial Coverings', 'C3_Cancel public events',
#        'C8_International travel controls', 'C5_Close public transport',
#        'H2_Testing policy', 'H7_Vaccination policy',
#        'C6_Stay at home requirements',
#        'C7_Restrictions on internal movement', 'C1_School closing',
#        'H3_Contact tracing', 'H1_Public information campaigns'],
#       dtype=object)

# %%
le = preprocessing.LabelEncoder()
le.fit(X['policy'])
print(le.classes_)
# Out:
# ['C1_School closing' 'C2_Workplace closing' 'C3_Cancel public events'
#  'C4_Restrictions on gatherings' 'C5_Close public transport'
#  'C6_Stay at home requirements' 'C7_Restrictions on internal movement'
#  'C8_International travel controls' 'H1_Public information campaigns'
#  'H2_Testing policy' 'H3_Contact tracing' 'H6_Facial Coverings'
#  'H7_Vaccination policy']

# %%
X['policy'] = pd.Series(le.transform(X['policy']))
original_policies_decoded = pd.Series(le.inverse_transform(X['policy']))
# Out:
# /var/folders/66/w1588p9n1654b1yky4q5nz580000gn/T/ipykernel_37377/2867200982.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['policy'] = pd.Series(le.transform(X['policy']))

# %% [markdown]
# ------

# %% [markdown]
# -------

# %% [markdown]
# # Train Models Here

# %%
y
# Out:
#       Y_TREND_caseInterpolate_MA7_14  Y_TRENDQUANT_caseInterpolate_MA7_14  \
# 0                           0.799121                            -0.028260
# 1                          -1.334114                            -0.826482
# 2                          -1.334114                            -1.247003
# 3                           0.799121                             0.663721
# 4                          -1.334114                            -0.133963
# 1581                                0.284779
# 1582                                0.055811
#
#       Y_SLOPE_caseInterpolate_gauss3_28
# 0                             -0.011448
# 1                             -0.837366
# 2                             -1.389629
# 3                              0.722548
# 4                             -0.127192
# ...                                 ...
# 1578                          -0.289041
# 1579                          -0.104552
# 1580                           0.029143
# 1581                           0.223813
# 1582                           0.051342
#
# [1583 rows x 27 columns]

# %%
X = X.apply(zscore)
y = y.apply(zscore)

# %%
from sklearn.datasets import load_iris
from sklearn import tree

# %%
clf = tree.DecisionTreeRegressor()

# %%
y_selected = y[['Y_TRENDQUANT_caseInterpolate_MA7_14']]

# %%
clf = clf.fit(X, y_selected)

# %%
dot_data = tree.export_graphviz(clf, out_file=None) 
graph = graphviz.Source(dot_data) 
graph.render("iris")
# Out:
# 'iris.pdf'

# %%
dot_data = tree.export_graphviz(clf, out_file=None, 
                     feature_names=X.columns.to_list(), 
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(dot_data)  
graph.render('op')
# Out:
# 'op.pdf'

# %%
# !open .

# %%
# Random Forest 

regr = RandomForestRegressor(max_depth=100, random_state=0)
regr.fit(X, y_selected)
# Out:
# /var/folders/66/w1588p9n1654b1yky4q5nz580000gn/T/ipykernel_37377/3596666854.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regr.fit(X, y_selected)
# RandomForestRegressor(max_depth=100, random_state=0)

# %%
def imp_df(column_names, importances):
    data = {
        'Feature': column_names,
        'Importance': importances,
    }
    df = pd.DataFrame(data) \
        .set_index('Feature') \
        .sort_values('Importance', ascending=False)

    return df

# %%
base_imp = imp_df(X.columns, regr.feature_importances_)
print(base_imp)
# Out:
#                                                  Importance
# Feature
# policy                                             0.469987
# metric_change                                      0.187818
# FD_moreThan10kCitizens                             0.021709
# S1_people_fully_vaccinated_per_hundred             0.019639
# S1_people_vaccinated                               0.018727
# S1_people_fully_vaccinated                         0.018476
# CEN_Without Health Care Coverage                   0.017234
# CEN_Hispanic or Latino (of any race)               0.016954
# S2_people_fully_vaccinated                         0.011627
# CEN_Total Employer Establishments                  0.011586
# CEN_Total Population                               0.010546
# S2_people_vaccinated                               0.010059
# S4_people_fully_vaccinated                         0.009749
# CEN_Total Housing Units                            0.009589
# FD_lessThan10kCitizens                             0.009407
# S4_people_vaccinated                               0.009008
# S3_people_fully_vaccinated                         0.008663
# S1_people_vaccinated_per_hundred                   0.008659
# HB_bed_Total                                       0.008466
# FD_fireResponseOnly                                0.007254
# S2_people_vaccinated_per_hundred                   0.006983
# CP_1_diff                                          0.006593
# HB_bed_Non-Profit                                  0.006566
# FD_totalFireDepartments                            0.006396
# OB_Prevalence                                      0.006327
# S4_people_vaccinated_per_hundred                   0.006258
# CP_2_diff                                          0.006098
# S3_people_vaccinated                               0.006059
# CEN_Employment Rate                                0.005834
# HB_bed_For-Profit                                  0.005448
# FD_adminAndFireResponse                            0.005350
# CEN_Total Households                               0.005269
# CP_0_diff                                          0.005022
# CEN_Median Household Income                        0.005008
# HB_bed_State/Local Government                      0.004344
# S2_people_fully_vaccinated_per_hundred             0.004335
# S3_people_fully_vaccinated_per_hundred             0.004251
# CEN_Bachelor's Degree or Higher                    0.004222
# S4_people_fully_vaccinated_per_hundred             0.004081
# S3_people_vaccinated_per_hundred                   0.003079
# SP_State Attorney General Political Affiliation    0.002351
# SP_State Senate Majority Political Affiliation     0.001913
# SP_State House Majority Political Affiliation      0.001833
# SP_Governor Political Affiliation                  0.001223
