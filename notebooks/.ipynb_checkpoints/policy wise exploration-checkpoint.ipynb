# %% [markdown]
# # A basic template to apply any models to train on the collected data

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from scipy.stats import zscore
from sklearn import preprocessing
pd.set_option('display.max_columns', None)
import graphviz
plt.rcParams['figure.figsize'] = [18, 10]

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
trainDF = pd.read_csv('../outputs/trainXY.csv',parse_dates=['date_implement'])
trainDF = trainDF.sample(frac=1)

# %%
trainDF.head()
trainDF = trainDF.dropna()

# %% [markdown]
# # Selecting a unique policy

# %%
policies = trainDF['policy'].unique()
policy_selected = policies[6]
print(f'Selected Policy: {policy_selected}')
trainDF = trainDF[trainDF['policy']==policy_selected]
# Out:
# Selected Policy: C4_Restrictions on gatherings

# %%
# Finalizing Indexes so we can drop state names 
trainDF = trainDF.reset_index(drop=True)

# Get a list of columns with features 
columns = trainDF.columns.to_list()

# %%
Y_columns = [x for x in columns if 'Y_' in x]

# %%
X_columns = [x for x in columns if 'Y_' not in x and 'Unnamed' not in x]

X_columns.remove('date_implement')
# X_columns.remove('policy')
X_columns.remove('state_x')
X_columns.remove('policy_type')
X_columns.remove('stateName')
X_columns.remove('CEN_stateCode')
X_columns.remove('submission_date')
X_columns.remove('state_y')

X_columns.remove('caseInterpolate_gauss3')
X_columns.remove('caseInterpolate_MA7')
X_columns.remove('caseInterpolate_savitzky31_3')
X_columns.remove('caseInterpolate_gauss8')
X_columns.remove('new_case_zscore')
X_columns.remove('new_case')
X_columns.remove('policy')

# %%
X = trainDF[X_columns]
y = trainDF[Y_columns]

# %%
y
# Out:
#      Y_TREND_caseInterpolate_MA7_14  Y_TRENDQUANT_caseInterpolate_MA7_14  \
# 0                              -1.0                            -3.530612
# 1                              -1.0                           -21.908163
# 2                               1.0                             6.551020
# 3                              -1.0                           -27.959184
# 4                              -1.0                            -8.959184
# ..                              ...                                  ...
# 226                             1.0                             2.061224
# 227                             1.0                             0.336735
# 228                            -1.0                           -99.306122
# 229                             1.0                             6.132653
# 230                             1.0                            12.438776
#
#      Y_SLOPE_caseInterpolate_MA7_14  Y_TREND_caseInterpolate_MA7_21  \
# 0                         -6.877802                            -1.0
# 1                        -31.682088                            -1.0
# 2                          3.431538                             1.0
# 3                        -18.735604                            -1.0
# 4                         -9.266374                            -1.0
# ..                              ...                             ...
# 226                       -3.515495                            -1.0
# 227                        0.071099                             1.0
# 228                      -97.343297                            -1.0
# 229                       17.615275                             1.0
# 230                       14.806264                             1.0
#
#      Y_TRENDQUANT_caseInterpolate_MA7_21  Y_SLOPE_caseInterpolate_MA7_21  \
# 0                              -6.748299                       -6.877802
# 1                             -22.462585                      -31.682088
# 2                               4.367347                        3.431538
# 3                             -18.918367                      -18.735604
# 4                              -8.809524                       -9.266374
# ..                                   ...                             ...
# 226                            -1.721088                       -3.515495
# 227                             0.224490                        0.071099
# 228                          -107.741497                      -97.343297
# 229                            12.265306                       17.615275
# 230                            13.789116                       14.806264
#
#      Y_TREND_caseInterpolate_MA7_28  Y_TRENDQUANT_caseInterpolate_MA7_28  \
# 0                              -1.0                            -3.663265
# 1                              -1.0                           -29.535714
# 2                               1.0                             3.275510
# 3                              -1.0                           -15.887755
# 4                              -1.0                            -7.091837
# ..                              ...                                  ...
# 226                            -1.0                            -3.770408
# 227                             1.0                             0.168367
# 228                            -1.0                           -61.984694
# 229                             1.0                            20.642857
# 230                             1.0                            13.316327
#
#      Y_SLOPE_caseInterpolate_MA7_28  Y_TREND_caseInterpolate_gauss8_14  \
# 0                         -6.877802                               -1.0
# 1                        -31.682088                               -1.0
# 2                          3.431538                                1.0
# 3                        -18.735604                               -1.0
# 4                         -9.266374                               -1.0
# ..                              ...                                ...
# 226                       -3.515495                                1.0
# 227                        0.071099                                1.0
# 228                      -97.343297                               -1.0
# 229                       17.615275                                1.0
# 230                       14.806264                                1.0
#
#      Y_TRENDQUANT_caseInterpolate_gauss8_14  \
# 0                                 -2.714286
# 1                                -23.714286
# 2                                  9.214286
# 3                                -17.714286
# 4                                 -3.000000
# ..                                      ...
# 226                                4.214286
# 227                                6.357143
# 228                              -96.285714
# 229                                7.714286
# 230                               12.428571
#
#      Y_SLOPE_caseInterpolate_gauss8_14  Y_TREND_caseInterpolate_gauss8_21  \
# 0                            -4.133846                               -1.0
# 1                           -28.477692                               -1.0
# 2                             6.052308                                1.0
# 3                           -16.282308                               -1.0
# 4                            -5.043077                               -1.0
# ..                                 ...                                ...
# 226                          -0.455385                                1.0
# 227                           2.991538                                1.0
# 228                         -85.182308                               -1.0
# 229                          13.109231                                1.0
# 230                          13.036923                                1.0
#
#      Y_TRENDQUANT_caseInterpolate_gauss8_21  \
# 0                                 -3.666667
# 1                                -27.190476
# 2                                  7.047619
# 3                                -16.476190
# 4                                 -4.333333
# ..                                      ...
# 226                                0.952381
# 227                                4.333333
# 228                              -87.571429
# 229                               11.571429
# 230                               12.761905
#
#      Y_SLOPE_caseInterpolate_gauss8_21  Y_TREND_caseInterpolate_gauss8_28  \
# 0                            -4.133846                               -1.0
# 1                           -28.477692                               -1.0
# 2                             6.052308                                1.0
# 3                           -16.282308                               -1.0
# 4                            -5.043077                               -1.0
# ..                                 ...                                ...
# 226                          -0.455385                               -1.0
# 227                           2.991538                                1.0
# 228                         -85.182308                               -1.0
# 229                          13.109231                                1.0
# 230                          13.036923                                1.0
#
#      Y_TRENDQUANT_caseInterpolate_gauss8_28  \
# 0                                 -3.892857
# 1                                -31.321429
# 2                                  5.500000
# 3                                -13.321429
# 4                                 -4.392857
# ..                                      ...
# 226                               -1.678571
# 227                                3.250000
# 228                              -69.928571
# 229                               14.035714
# 230                               11.750000
#
#      Y_SLOPE_caseInterpolate_gauss8_28  Y_TREND_caseInterpolate_gauss3_14  \
# 0                            -4.133846                               -1.0
# 1                           -28.477692                               -1.0
# 2                             6.052308                                1.0
# 3                           -16.282308                               -1.0
# 4                            -5.043077                               -1.0
# ..                                 ...                                ...
# 226                          -0.455385                                1.0
# 227                           2.991538                                1.0
# 228                         -85.182308                               -1.0
# 229                          13.109231                                1.0
# 230                          13.036923                                1.0
#
#      Y_TRENDQUANT_caseInterpolate_gauss3_14  \
# 0                                 -1.857143
# 1                                -20.928571
# 2                                  8.285714
# 3                                -21.500000
# 4                                 -2.357143
# ..                                      ...
# 226                                4.071429
# 227                                1.714286
# 228                             -101.285714
# 229                                4.500000
# 230                               13.142857
#
#      Y_SLOPE_caseInterpolate_gauss3_14  Y_TREND_caseInterpolate_gauss3_21  \
# 0                            -5.726923                               -1.0
# 1                           -26.100000                               -1.0
# 2                             5.103077                                1.0
# 3                           -21.546154                               -1.0
# 4                            -7.695385                               -1.0
# ..                                 ...                                ...
# 226                          -0.981538                                1.0
# 227                           0.530000                                1.0
# 228                        -104.553077                               -1.0
# 229                          12.485385                                1.0
# 230                          14.208462                                1.0
#
#      Y_TRENDQUANT_caseInterpolate_gauss3_21  \
# 0                                 -5.428571
# 1                                -21.476190
# 2                                  5.952381
# 3                                -20.761905
# 4                                 -6.000000
# ..                                      ...
# 226                                0.285714
# 227                                1.142857
# 228                             -110.142857
# 229                                9.904762
# 230                               14.285714
#
#      Y_SLOPE_caseInterpolate_gauss3_21  Y_TREND_caseInterpolate_gauss3_28  \
# 0                            -5.726923                               -1.0
# 1                           -26.100000                               -1.0
# 2                             5.103077                                1.0
# 3                           -21.546154                               -1.0
# 4                            -7.695385                               -1.0
# ..                                 ...                                ...
# 226                          -0.981538                               -1.0
# 227                           0.530000                                1.0
# 228                        -104.553077                               -1.0
# 229                          12.485385                                1.0
# 230                          14.208462                                1.0
#
#      Y_TRENDQUANT_caseInterpolate_gauss3_28  Y_SLOPE_caseInterpolate_gauss3_28
# 0                                 -4.357143                          -5.726923
# 1                                -27.750000                         -26.100000
# 2                                  4.464286                           5.103077
# 3                                -16.857143                         -21.546154
# 4                                 -4.785714                          -7.695385
# ..                                      ...                                ...
# 226                               -2.607143                          -0.981538
# 227                                0.857143                           0.530000
# 228                              -76.285714                        -104.553077
# 229                               15.285714                          12.485385
# 230                               14.464286                          14.208462
#
# [231 rows x 27 columns]

# %% [markdown]
# # Encoding Policy Names

# %%
# X['policy'].unique()

# %%
# le = preprocessing.LabelEncoder()
# le.fit(X['policy'])
# print(le.classes_)

# %%
# X['policy'] = pd.Series(le.transform(X['policy']))
# original_policies_decoded = pd.Series(le.inverse_transform(X['policy']))

# %%
# for i in range(len(le.classes_)):
#     print(f'{i}: {le.classes_[i]}')

# %%
# unique_policy = X['policy'].unique()

# %% [markdown]
# ------

# %% [markdown]
# -------

# %% [markdown]
# # Train Models Here

# %%
y
# Out:
#      Y_TREND_caseInterpolate_MA7_14  Y_TRENDQUANT_caseInterpolate_MA7_14  \
# 0                              -1.0                            -3.530612
# 1                              -1.0                           -21.908163
# 2                               1.0                             6.551020
# 3                              -1.0                           -27.959184
# 4                              -1.0                            -8.959184
# ..                              ...                                  ...
# 226                             1.0                             2.061224
# 227                             1.0                             0.336735
# 228                            -1.0                           -99.306122
# 229                             1.0                             6.132653
# 230                             1.0                            12.438776
#
#      Y_SLOPE_caseInterpolate_MA7_14  Y_TREND_caseInterpolate_MA7_21  \
# 0                         -6.877802                            -1.0
# 1                        -31.682088                            -1.0
# 2                          3.431538                             1.0
# 3                        -18.735604                            -1.0
# 4                         -9.266374                            -1.0
# ..                              ...                             ...
# 226                       -3.515495                            -1.0
# 227                        0.071099                             1.0
# 228                      -97.343297                            -1.0
# 229                       17.615275                             1.0
# 230                       14.806264                             1.0
#
#      Y_TRENDQUANT_caseInterpolate_MA7_21  Y_SLOPE_caseInterpolate_MA7_21  \
# 0                              -6.748299                       -6.877802
# 1                             -22.462585                      -31.682088
# 2                               4.367347                        3.431538
# 3                             -18.918367                      -18.735604
# 4                              -8.809524                       -9.266374
# ..                                   ...                             ...
# 226                            -1.721088                       -3.515495
# 227                             0.224490                        0.071099
# 228                          -107.741497                      -97.343297
# 229                            12.265306                       17.615275
# 230                            13.789116                       14.806264
#
#      Y_TREND_caseInterpolate_MA7_28  Y_TRENDQUANT_caseInterpolate_MA7_28  \
# 0                              -1.0                            -3.663265
# 1                              -1.0                           -29.535714
# 2                               1.0                             3.275510
# 3                              -1.0                           -15.887755
# 4                              -1.0                            -7.091837
# ..                              ...                                  ...
# 226                            -1.0                            -3.770408
# 227                             1.0                             0.168367
# 228                            -1.0                           -61.984694
# 229                             1.0                            20.642857
# 230                             1.0                            13.316327
#
#      Y_SLOPE_caseInterpolate_MA7_28  Y_TREND_caseInterpolate_gauss8_14  \
# 0                         -6.877802                               -1.0
# 1                        -31.682088                               -1.0
# 2                          3.431538                                1.0
# 3                        -18.735604                               -1.0
# 4                         -9.266374                               -1.0
# ..                              ...                                ...
# 226                       -3.515495                                1.0
# 227                        0.071099                                1.0
# 228                      -97.343297                               -1.0
# 229                       17.615275                                1.0
# 230                       14.806264                                1.0
#
#      Y_TRENDQUANT_caseInterpolate_gauss8_14  \
# 0                                 -2.714286
# 1                                -23.714286
# 2                                  9.214286
# 3                                -17.714286
# 4                                 -3.000000
# ..                                      ...
# 226                                4.214286
# 227                                6.357143
# 228                              -96.285714
# 229                                7.714286
# 230                               12.428571
#
#      Y_SLOPE_caseInterpolate_gauss8_14  Y_TREND_caseInterpolate_gauss8_21  \
# 0                            -4.133846                               -1.0
# 1                           -28.477692                               -1.0
# 2                             6.052308                                1.0
# 3                           -16.282308                               -1.0
# 4                            -5.043077                               -1.0
# ..                                 ...                                ...
# 226                          -0.455385                                1.0
# 227                           2.991538                                1.0
# 228                         -85.182308                               -1.0
# 229                          13.109231                                1.0
# 230                          13.036923                                1.0
#
#      Y_TRENDQUANT_caseInterpolate_gauss8_21  \
# 0                                 -3.666667
# 1                                -27.190476
# 2                                  7.047619
# 3                                -16.476190
# 4                                 -4.333333
# ..                                      ...
# 226                                0.952381
# 227                                4.333333
# 228                              -87.571429
# 229                               11.571429
# 230                               12.761905
#
#      Y_SLOPE_caseInterpolate_gauss8_21  Y_TREND_caseInterpolate_gauss8_28  \
# 0                            -4.133846                               -1.0
# 1                           -28.477692                               -1.0
# 2                             6.052308                                1.0
# 3                           -16.282308                               -1.0
# 4                            -5.043077                               -1.0
# ..                                 ...                                ...
# 226                          -0.455385                               -1.0
# 227                           2.991538                                1.0
# 228                         -85.182308                               -1.0
# 229                          13.109231                                1.0
# 230                          13.036923                                1.0
#
#      Y_TRENDQUANT_caseInterpolate_gauss8_28  \
# 0                                 -3.892857
# 1                                -31.321429
# 2                                  5.500000
# 3                                -13.321429
# 4                                 -4.392857
# ..                                      ...
# 226                               -1.678571
# 227                                3.250000
# 228                              -69.928571
# 229                               14.035714
# 230                               11.750000
#
#      Y_SLOPE_caseInterpolate_gauss8_28  Y_TREND_caseInterpolate_gauss3_14  \
# 0                            -4.133846                               -1.0
# 1                           -28.477692                               -1.0
# 2                             6.052308                                1.0
# 3                           -16.282308                               -1.0
# 4                            -5.043077                               -1.0
# ..                                 ...                                ...
# 226                          -0.455385                                1.0
# 227                           2.991538                                1.0
# 228                         -85.182308                               -1.0
# 229                          13.109231                                1.0
# 230                          13.036923                                1.0
#
#      Y_TRENDQUANT_caseInterpolate_gauss3_14  \
# 0                                 -1.857143
# 1                                -20.928571
# 2                                  8.285714
# 3                                -21.500000
# 4                                 -2.357143
# ..                                      ...
# 226                                4.071429
# 227                                1.714286
# 228                             -101.285714
# 229                                4.500000
# 230                               13.142857
#
#      Y_SLOPE_caseInterpolate_gauss3_14  Y_TREND_caseInterpolate_gauss3_21  \
# 0                            -5.726923                               -1.0
# 1                           -26.100000                               -1.0
# 2                             5.103077                                1.0
# 3                           -21.546154                               -1.0
# 4                            -7.695385                               -1.0
# ..                                 ...                                ...
# 226                          -0.981538                                1.0
# 227                           0.530000                                1.0
# 228                        -104.553077                               -1.0
# 229                          12.485385                                1.0
# 230                          14.208462                                1.0
#
#      Y_TRENDQUANT_caseInterpolate_gauss3_21  \
# 0                                 -5.428571
# 1                                -21.476190
# 2                                  5.952381
# 3                                -20.761905
# 4                                 -6.000000
# ..                                      ...
# 226                                0.285714
# 227                                1.142857
# 228                             -110.142857
# 229                                9.904762
# 230                               14.285714
#
#      Y_SLOPE_caseInterpolate_gauss3_21  Y_TREND_caseInterpolate_gauss3_28  \
# 0                            -5.726923                               -1.0
# 1                           -26.100000                               -1.0
# 2                             5.103077                                1.0
# 3                           -21.546154                               -1.0
# 4                            -7.695385                               -1.0
# ..                                 ...                                ...
# 226                          -0.981538                               -1.0
# 227                           0.530000                                1.0
# 228                        -104.553077                               -1.0
# 229                          12.485385                                1.0
# 230                          14.208462                                1.0
#
#      Y_TRENDQUANT_caseInterpolate_gauss3_28  Y_SLOPE_caseInterpolate_gauss3_28
# 0                                 -4.357143                          -5.726923
# 1                                -27.750000                         -26.100000
# 2                                  4.464286                           5.103077
# 3                                -16.857143                         -21.546154
# 4                                 -4.785714                          -7.695385
# ..                                      ...                                ...
# 226                               -2.607143                          -0.981538
# 227                                0.857143                           0.530000
# 228                              -76.285714                        -104.553077
# 229                               15.285714                          12.485385
# 230                               14.464286                          14.208462
#
# [231 rows x 27 columns]

# %%
X = X.apply(zscore)
y = y.apply(zscore)

# %%
from sklearn.datasets import load_iris
from sklearn import tree

# %%
clf = tree.DecisionTreeRegressor()

# %%
y_selected = y[['Y_TRENDQUANT_caseInterpolate_MA7_14']]

# %%
clf = clf.fit(X, y_selected)

# %%
# dot_data = tree.export_graphviz(clf, out_file=None) 
# graph = graphviz.Source(dot_data) 
# graph.render("tree")

# %%
dot_data = tree.export_graphviz(clf, out_file=None, 
                     feature_names=X.columns.to_list(), 
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(dot_data)  
graph.render(f'../outputs/TREEOP_{policy_selected}')
# Out:
# '../outputs/TREEOP_C4_Restrictions on gatherings.pdf'

# %% [markdown]
# # Most Important Features

# %%
# Random Forest 

regr = RandomForestRegressor(max_depth=100, random_state=0)
regr.fit(X, y_selected)
# Out:
# /var/folders/66/w1588p9n1654b1yky4q5nz580000gn/T/ipykernel_9725/3596666854.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regr.fit(X, y_selected)
# RandomForestRegressor(max_depth=100, random_state=0)

# %%
def imp_df(column_names, importances):
    data = {
        'Feature': column_names,
        'Importance': importances,
    }
    df = pd.DataFrame(data) \
        .set_index('Feature') \
        .sort_values('Importance', ascending=False)

    return df

# %%
base_imp = imp_df(X.columns, regr.feature_importances_)
print(base_imp)
# Out:
#                                                  Importance
# Feature
# metric_change                                      0.441014
# CEN_Without Health Care Coverage                   0.047322
# FD_adminAndFireResponse                            0.029803
# FD_totalFireDepartments                            0.028892
# FD_moreThan10kCitizens                             0.026201
# S4_people_vaccinated                               0.024684
# OB_Prevalence                                      0.024538
# CEN_Total Housing Units                            0.023080
# CEN_Employment Rate                                0.022389
# FD_lessThan10kCitizens                             0.021530
# CEN_Total Population                               0.018907
# S3_people_fully_vaccinated                         0.018509
# S2_people_vaccinated                               0.016685
# S1_people_vaccinated                               0.016037
# S1_people_vaccinated_per_hundred                   0.015404
# S3_people_vaccinated                               0.015230
# HB_bed_For-Profit                                  0.014081
# CEN_Total Households                               0.013576
# CP_0_diff                                          0.013207
# CEN_Hispanic or Latino (of any race)               0.012996
# CEN_Total Employer Establishments                  0.012408
# CP_1_diff                                          0.012124
# FD_fireResponseOnly                                0.011019
# HB_bed_State/Local Government                      0.010887
# S4_people_fully_vaccinated                         0.010646
# S1_people_fully_vaccinated_per_hundred             0.010087
# S2_people_vaccinated_per_hundred                   0.009575
# S2_people_fully_vaccinated                         0.009555
# S1_people_fully_vaccinated                         0.008678
# CEN_Median Household Income                        0.006908
# S2_people_fully_vaccinated_per_hundred             0.006866
# CP_2_diff                                          0.006651
# HB_bed_Total                                       0.006432
# HB_bed_Non-Profit                                  0.006384
# S4_people_vaccinated_per_hundred                   0.005422
# S3_people_fully_vaccinated_per_hundred             0.005114
# S3_people_vaccinated_per_hundred                   0.005023
# CEN_Bachelor's Degree or Higher                    0.004422
# S4_people_fully_vaccinated_per_hundred             0.002159
# SP_State Senate Majority Political Affiliation     0.002081
# SP_State Attorney General Political Affiliation    0.001494
# SP_State House Majority Political Affiliation      0.001208
# SP_Governor Political Affiliation                  0.000773
